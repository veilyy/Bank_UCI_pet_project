# %%
import os
import sys
sys.path.append('..')

# %%
import pprint
import os
import pandas as pd
import numpy as np
import subprocess
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import joblib
from src.preprocessing import *

# %%
df = pd.read_csv('../data/raw/bank-additional-full.csv', sep=';')

# %%
result = preprocessing(df)

# %% [markdown]
# # Сохранение данных

# %%
result['X_train'].to_csv('D:\\Projects\\bank_pet_project\\data\\processed\\X_train.csv', index=False)
result['y_train'].to_csv('D:\\Projects\\bank_pet_project\\data\\processed\\y_train.csv', index=False)
result['X_test'].to_csv('D:\\Projects\\bank_pet_project\\data\\processed\\X_test.csv', index=False)
result['y_test'].to_csv('D:\\Projects\\bank_pet_project\\data\\processed\\y_test.csv', index=False)
joblib.dump(result['scaler'], 'D:\\Projects\\bank_pet_project\\models/scaler.pkl')
# Out:
# ['D:\\Projects\\bank_pet_project\\models/scaler.pkl']
